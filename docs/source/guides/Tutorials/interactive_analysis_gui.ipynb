# %% [markdown]
# # Interactive Analaysis GUI
#
# *Author: [Andrew Causer](https://agc888.github.io/OspreyAI)*
#
# This notebook is a tutorial of how to use the interactive analysis GUI implmeneted in *goatpy*. This interactive GUI is build using `Napari`, for more infomation on how to use napari please visit [here](https://napari.org/).
#
# For more infomation on how to run general analysis using *goatpy* please visit the [Getting Started](https://goatpy.readthedocs.io/en/latest/guides/getting_started.html#Loading-and-Aligning-Data) page.

# %% [markdown]
# ## Pre-Analysis: Peak Selection
#
# Using `goatpy` we can read in our .imzml files and create `SpatialData` objects. These objects can then be visalised with `goatpy's` napari-based viewer.

# %%
import goatpy as gp
# Out:
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %%
raw_data = gp.glyco_spatialdata(imzml_path="./Documents/AD_resolution_change_check_10um_actual_10012020_2.imzML")
# Out:
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/goatpy/io.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/anndata.py:381: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/spatialdata/models/models.py:1144: UserWarning: Converting `region_key: region` to categorical dtype.
#   return convert_region_column_to_categorical(adata)

# %%
from spatialdata import read_zarr
raw_data = read_zarr("/Users/andrewcauser/Documents/Griffith/test_data/ovarian_raw.zarr")
# Out:
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
viewer = gp.launch_goatpy_gui(raw_data)
# Out:
# 2026-06-20 00:14:15.556 | WARNING  | napari_spatialdata._viewer:__init__:57 - Due to Shift-L being used as shortcut in napari, it is being deprecated and might not link a new layer to an existing SpatialData object in the viewer. Please use ⌘-L on MacOS or else Ctrl-L.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# [goatpy GUI] Added 'pixels' (shapes) in 'global'
# INFO: Please wait for the current operation to finish.
# [goatpy GUI] Added 'centroids' (points) in 'global'
# [goatpy GUI] Could not switch coordinate system: aligned not present as coordinate system in any of the spatialdata objects
# [goatpy GUI] Ready
# 16455 pixels · 108 peaks
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession MS:1002302 found with incorrect name "Bruker Container file". Updating name to "Bruker Container format".
#   warn(
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/pyimzml/ontology/ontology.py:92: UserWarning: Accession IMS:1000046 found with incorrect name "pixel size". Updating name to "pixel size (x)".
#   warn(
# INFO: No Annotations layer found in SpatialData.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:21.450 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:21.465 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:30.561 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-06-20 00:14:30.645 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:30.660 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:34.990 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:35.007 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:35.810 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:35.827 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:36.661 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:36.676 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:36.695 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-06-20 00:14:36.698 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# 2026-06-20 00:14:36.722 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2026-06-20 00:14:36.736 | DEBUG    | napari_spatialdata._view:_on_layer_update:569 - Updating layer.
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/napari/layers/shapes/shapes.py:1153: UserWarning: _face_color_property was not set, setting to: _goatpy_viz
#   warnings.warn(
# INFO: Layer updated: 933.4000 (933.40)

# %% [markdown]
# ## Post-Analysis: Data Visualisation
#
# Using `SpatialData` pre-build data storage structure (`.zarr`) we can easily load our already analysed

# %%
sdata = read_zarr("/Users/andrewcauser/Documents/Griffith/test_data/ovarian_final.zarr")
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /Users/andrewcauser/anaconda3/envs/goatpy/lib/python3.10/site-packages/zarr/creation.py:614: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)

# %%
viewer = gp.launch_goatpy_gui(raw_data)
